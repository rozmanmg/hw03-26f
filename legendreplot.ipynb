# %% [markdown]
# # Legendre polynomial

# %% [markdown]
# **Legendre polynomials** is a particular kind of *special
# functions* that are important in physics and applied mathematics.
#
# Legendre polynomials are defined as follows:
#
# $$P_n(x)= \frac{1}{2^n \, n!} \, \frac{\mathrm{d}^n}{\mathrm{d}x^n} \, \left(x^2 - 1\right)^n,
# \qquad n = 0, 1, \ldots .$$
#
# The first few Legendre polynomials are as follows:
#
# $$P_{0}(x) = 1, \quad P_{1}(x) = x , \quad P_2(x) = your-markdown-code-here,
#     \quad P_3(x) = your-markdown-code-here .$$
#
# The polynomials are named after the mathematician Adrien-Marie Legendre.
#
# Legendre polynomials $P_n(x)$ satisfy the following recurrence relations:
#
# $$(n + 1) \, P_{n+1}(x) = your-markdown-code-here, \quad n = 1, 2, \ldots$$

# %% [markdown]
# Load plotting library:

# %%
using PythonPlot

# %% [markdown]
# #### Implementation of Legandre polynomials using foor loop:

# %%
"""
    mylegendre(n, x)

Calculate Legendre polynomial P_n(x) using the recurrence relation    
(n+1)P_{n+1} = (2*n+1)*x*P_n - n*P_{n-1}
"""
function mylegendre(n::Int, x)

    # your code here
    
end

# %% [markdown]
# Copy your AI prompts you used for coding `mylegendre` function: ....

# %% [markdown]
# #### Implementation of Legandre polynomials using recursive algorithm:

# %%
"""
    mylegendre_r(n, x)

Calculate Legendre polynomial P_n(x) using recursion algorithm and 
the recurrence relation (n+1)P_{n+1} = (2*n+1)*x*P_n - n*P_{n-1}
"""
function mylegendre_r(n::Int, x)

    # your code here
    
end

# %% [markdown]
# Copy your AI prompts you used for coding `mylegendre_r` function: ....

# %% [markdown]
# #### Compare results produced by your implementations:

# %%
mylegendre_r(0, 0.5) == mylegendre(0, 0.5)

# %%
mylegendre_r(1, 0.5) == mylegendre(1, 0.5)

# %%
mylegendre_r(2, 0.5) == mylegendre(2, 0.5)

# %%
mylegendre_r(3, 0.5) == mylegendre(3, 0.5)

# %% [markdown]
# #### Compare performance of the code:

# %%
@time mylegendre(46, 1.0)

# %%
@time mylegendre_r(46, 1.0)

# %% [markdown]
# Present your perfomance conclusions: ....

# %% [markdown]
# #### Plots

# %%
np = 200
x = range(-1.0, 1.0, np);

# %%
for n in [2, 3, 5]
    y = mylegendre.(n, x);
    plot(x, y, label=L"P_{%$n}(x)")
end

# grid ...
# legend ...
# title ...
# xlabel ...
# ylabel ...
